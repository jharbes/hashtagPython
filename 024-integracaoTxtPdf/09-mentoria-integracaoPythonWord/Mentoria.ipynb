# %%
# !pip install python-docx

# %%
from docx import Document

# criando o documento no Python
documento = Document()

faturamento = 1000

# aqui você edita tudo o que você quer
texto = f"""Fala Lira,

O faturamento da empresa ontem foi de R${faturamento}

Tamo junto, abs.
"""

paragrafo = documento.add_paragraph(texto)

# %% [markdown]
# ### formatação

# %%
# Pt vem de pontos que seria o tamanho da fonte
# RGBColor é das cores
# Cm é de centimetros para editar tamanho de imagem, tamanho de margem, etc
from docx.shared import Pt, RGBColor, Cm # valores de formatação

# permite criar um estilo de formatação (determina um conjunto de características para a fonte como cor, tipo de fonte, tamanho, etc)
from docx.enum.style import WD_STYLE_TYPE

# Criamos um estilo para ser utilizado (conjunto de caracteristicas do texto)
# 'EstiloLira' é o nome do estilo que está sendo criado
paragrafo.style = documento.styles.add_style("EstiloLira", WD_STYLE_TYPE.PARAGRAPH)

paragrafo.style.font.name = "Algerian" # nome da fonte como está no word
paragrafo.style.font.size = Pt(15) # tamanho da fonte no padrao do word
paragrafo.style.font.bold = True # negrito ligado
paragrafo.style.font.italic = True # italico ligado
paragrafo.style.font.underline = True # sublinhado ligado
paragrafo.style.font.color.rgb = RGBColor(255, 0, 0) # cor escolhida

# %%
# criaremos um novo paragrafo, porem o estilo criado anteriormente somente sera aplicado a esse paragrafo caso passemos seu nome no segundo argumento da funcao
paragrafo = documento.add_paragraph("PS: A quantidade de produtos vendidos foi de 10","EstiloLira")


### usando um estilo que já existe no word

# vendo os estilos diponiveis no word:
for estilo in documento.styles:
    print(estilo)

# adicionando paragrafo com estilo diferente
paragrafo = documento.add_paragraph("testando estilos aleatorios","macro")
# Out:
# _ParagraphStyle('Normal') id: 2806921375504
# _ParagraphStyle('Header') id: 2806921375312
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2F10>
# _ParagraphStyle('Footer') id: 2806921375312
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2F10>
# _ParagraphStyle('Heading 1') id: 2806921375312
# _ParagraphStyle('Heading 2') id: 2806921375504
# _ParagraphStyle('Heading 3') id: 2806921375312
# _ParagraphStyle('Heading 4') id: 2806921375504
# _ParagraphStyle('Heading 5') id: 2806921375312
# _ParagraphStyle('Heading 6') id: 2806921375504
# _ParagraphStyle('Heading 7') id: 2806921375312
# _ParagraphStyle('Heading 8') id: 2806921375504
# _ParagraphStyle('Heading 9') id: 2806921375312
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2F10>
# _TableStyle('Normal Table') id: 2806921375312
# <docx.styles.style._NumberingStyle object at 0x0000028D898D2F10>
# _ParagraphStyle('No Spacing') id: 2806921375312
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2F10>
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2E50>
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2F10>
# _ParagraphStyle('Title') id: 2806921375312
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2F10>
# _ParagraphStyle('Subtitle') id: 2806921375312
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2F10>
# _ParagraphStyle('List Paragraph') id: 2806921375312
# _ParagraphStyle('Body Text') id: 2806921375504
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2E50>
# _ParagraphStyle('Body Text 2') id: 2806921375504
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2E50>
# _ParagraphStyle('Body Text 3') id: 2806921375504
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2E50>
# _ParagraphStyle('List') id: 2806921375504
# _ParagraphStyle('List 2') id: 2806921375312
# _ParagraphStyle('List 3') id: 2806921375504
# _ParagraphStyle('List Bullet') id: 2806921375312
# _ParagraphStyle('List Bullet 2') id: 2806921375504
# _ParagraphStyle('List Bullet 3') id: 2806921375312
# _ParagraphStyle('List Number') id: 2806921375504
# _ParagraphStyle('List Number 2') id: 2806921375312
# _ParagraphStyle('List Number 3') id: 2806921375504
# _ParagraphStyle('List Continue') id: 2806921375312
# _ParagraphStyle('List Continue 2') id: 2806921375504
# _ParagraphStyle('List Continue 3') id: 2806921375312
# _ParagraphStyle('macro') id: 2806921375504
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2E50>
# _ParagraphStyle('Quote') id: 2806921375504
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2E50>
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2F10>
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2E50>
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2F10>
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2E50>
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2F10>
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2E50>
# _ParagraphStyle('Caption') id: 2806921375504
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2E50>
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2F10>
# _ParagraphStyle('Intense Quote') id: 2806921375312
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2F10>
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2E50>
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2F10>
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2E50>
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2F10>
# <docx.styles.style._CharacterStyle object at 0x0000028D898D2E50>
# _ParagraphStyle('TOC Heading') id: 2806921375504
# _TableStyle('Table Grid') id: 2806921375312
# _TableStyle('Light Shading') id: 2806921375504
# _TableStyle('Light Shading Accent 1') id: 2806921375312
# _TableStyle('Light Shading Accent 2') id: 2806921375504
# _TableStyle('Light Shading Accent 3') id: 2806921375312
# _TableStyle('Light Shading Accent 4') id: 2806921375504
# _TableStyle('Light Shading Accent 5') id: 2806921375312
# _TableStyle('Light Shading Accent 6') id: 2806921375504
# _TableStyle('Light List') id: 2806921375312
# _TableStyle('Light List Accent 1') id: 2806921375504
# _TableStyle('Light List Accent 2') id: 2806921375312
# _TableStyle('Light List Accent 3') id: 2806921375504
# _TableStyle('Light List Accent 4') id: 2806921375312
# _TableStyle('Light List Accent 5') id: 2806921375504
# _TableStyle('Light List Accent 6') id: 2806921375312
# _TableStyle('Light Grid') id: 2806921375504
# _TableStyle('Light Grid Accent 1') id: 2806921375312
# _TableStyle('Light Grid Accent 2') id: 2806921375504
# _TableStyle('Light Grid Accent 3') id: 2806921375312
# _TableStyle('Light Grid Accent 4') id: 2806921375504
# _TableStyle('Light Grid Accent 5') id: 2806921375312
# _TableStyle('Light Grid Accent 6') id: 2806921375504
# _TableStyle('Medium Shading 1') id: 2806921375312
# _TableStyle('Medium Shading 1 Accent 1') id: 2806921375504
# _TableStyle('Medium Shading 1 Accent 2') id: 2806921375312
# _TableStyle('Medium Shading 1 Accent 3') id: 2806921375504
# _TableStyle('Medium Shading 1 Accent 4') id: 2806921375312
# _TableStyle('Medium Shading 1 Accent 5') id: 2806921375504
# _TableStyle('Medium Shading 1 Accent 6') id: 2806921375312
# _TableStyle('Medium Shading 2') id: 2806921375504
# _TableStyle('Medium Shading 2 Accent 1') id: 2806921375312
# _TableStyle('Medium Shading 2 Accent 2') id: 2806921375504
# _TableStyle('Medium Shading 2 Accent 3') id: 2806921375312
# _TableStyle('Medium Shading 2 Accent 4') id: 2806921375504
# _TableStyle('Medium Shading 2 Accent 5') id: 2806921375312
# _TableStyle('Medium Shading 2 Accent 6') id: 2806921375504
# _TableStyle('Medium List 1') id: 2806921375312
# _TableStyle('Medium List 1 Accent 1') id: 2806921375504
# _TableStyle('Medium List 1 Accent 2') id: 2806921375312
# _TableStyle('Medium List 1 Accent 3') id: 2806921375504
# _TableStyle('Medium List 1 Accent 4') id: 2806921375312
# _TableStyle('Medium List 1 Accent 5') id: 2806921375504
# _TableStyle('Medium List 1 Accent 6') id: 2806921375312
# _TableStyle('Medium List 2') id: 2806921375504
# _TableStyle('Medium List 2 Accent 1') id: 2806921375312
# _TableStyle('Medium List 2 Accent 2') id: 2806921375504
# _TableStyle('Medium List 2 Accent 3') id: 2806921375312
# _TableStyle('Medium List 2 Accent 4') id: 2806921375504
# _TableStyle('Medium List 2 Accent 5') id: 2806921375312
# _TableStyle('Medium List 2 Accent 6') id: 2806921375504
# _TableStyle('Medium Grid 1') id: 2806921375312
# _TableStyle('Medium Grid 1 Accent 1') id: 2806921375504
# _TableStyle('Medium Grid 1 Accent 2') id: 2806921375312
# _TableStyle('Medium Grid 1 Accent 3') id: 2806921375504
# _TableStyle('Medium Grid 1 Accent 4') id: 2806921375312
# _TableStyle('Medium Grid 1 Accent 5') id: 2806921375504
# _TableStyle('Medium Grid 1 Accent 6') id: 2806921375312
# _TableStyle('Medium Grid 2') id: 2806921375504
# _TableStyle('Medium Grid 2 Accent 1') id: 2806921375312
# _TableStyle('Medium Grid 2 Accent 2') id: 2806921375504
# _TableStyle('Medium Grid 2 Accent 3') id: 2806921375312
# _TableStyle('Medium Grid 2 Accent 4') id: 2806921375504
# _TableStyle('Medium Grid 2 Accent 5') id: 2806921375312
# _TableStyle('Medium Grid 2 Accent 6') id: 2806921375504
# _TableStyle('Medium Grid 3') id: 2806921375312
# _TableStyle('Medium Grid 3 Accent 1') id: 2806921375504
# _TableStyle('Medium Grid 3 Accent 2') id: 2806921375312
# _TableStyle('Medium Grid 3 Accent 3') id: 2806921375504
# _TableStyle('Medium Grid 3 Accent 4') id: 2806921375312
# _TableStyle('Medium Grid 3 Accent 5') id: 2806921375504
# _TableStyle('Medium Grid 3 Accent 6') id: 2806921375312
# _TableStyle('Dark List') id: 2806921375504
# _TableStyle('Dark List Accent 1') id: 2806921375312
# _TableStyle('Dark List Accent 2') id: 2806921375504
# _TableStyle('Dark List Accent 3') id: 2806921375312
# _TableStyle('Dark List Accent 4') id: 2806921375504
# _TableStyle('Dark List Accent 5') id: 2806921375312
# _TableStyle('Dark List Accent 6') id: 2806921375504
# _TableStyle('Colorful Shading') id: 2806921375312
# _TableStyle('Colorful Shading Accent 1') id: 2806921375504
# _TableStyle('Colorful Shading Accent 2') id: 2806921375312
# _TableStyle('Colorful Shading Accent 3') id: 2806921375504
# _TableStyle('Colorful Shading Accent 4') id: 2806921375312
# _TableStyle('Colorful Shading Accent 5') id: 2806921375504
# _TableStyle('Colorful Shading Accent 6') id: 2806921375312
# _TableStyle('Colorful List') id: 2806921375504
# _TableStyle('Colorful List Accent 1') id: 2806921375312
# _TableStyle('Colorful List Accent 2') id: 2806921375504
# _TableStyle('Colorful List Accent 3') id: 2806921375312
# _TableStyle('Colorful List Accent 4') id: 2806921375504
# _TableStyle('Colorful List Accent 5') id: 2806921375312
# _TableStyle('Colorful List Accent 6') id: 2806921375504
# _TableStyle('Colorful Grid') id: 2806921375312
# _TableStyle('Colorful Grid Accent 1') id: 2806921375504
# _TableStyle('Colorful Grid Accent 2') id: 2806921375312
# _TableStyle('Colorful Grid Accent 3') id: 2806921375504
# _TableStyle('Colorful Grid Accent 4') id: 2806921375312
# _TableStyle('Colorful Grid Accent 5') id: 2806921375504
# _TableStyle('Colorful Grid Accent 6') id: 2806921375312
# _ParagraphStyle('EstiloLira') id: 2806921375504

# %%
# implementando tudo que fizemos no Python no Texto.docx
documento.save("Texto.docx")

# %% [markdown]
# ### Aproveitando um template do word

# %%
### Aproveitando um template do word, assim nao precisa criar o estilo no python, a criacao sera no word, depois salvaremos um arquivo (no caso o template.docx) e iremos aproveita-lo abrindo o Document com ele

template = Document("template.docx")

# %%
paragrafo = template.add_paragraph("Contrato de Prestação de Serviço", "novoEstiloTeste")
template.save("NovoArquivo.docx")

# %% [markdown]
# ### Adicionar texto com edição dentro do texto

# %%
from docx import Document

# criando o documento no Python
documento = Document()

faturamento = 1000

# aqui você edita tudo o que você quer
texto = f"""Fala Lira,

O faturamento da empresa ontem foi de """
paragrafo = documento.add_paragraph(texto) 

# adiciona um texto no mesmo paragrafo com o estilo em negrito
paragrafo.add_run(f"R${faturamento}").bold = True

texto_final = "Tamo junto, abs."
paragrafo = documento.add_paragraph(texto_final)



documento.save("Texto2.docx")

# %% [markdown]
# ### Controle de Margem e Seções

# %%
# para alinhar o paragrafo (esquerda, direita, justificado ou centralizado)
from docx.enum.text import WD_PARAGRAPH_ALIGNMENT

# criando o documento no Python
documento = Document()


# as margens do documento passamos em centimetros com a funcao Cm
for secao in documento.sections:
    secao.top_margin = Cm(0.5)
    secao.bottom_margin = Cm(1)
    secao.left_margin = Cm(1)
    secao.right_margin = Cm(1)


faturamento = 1000

# aqui você edita tudo o que você quer
texto = f"""Fala Lira,

O faturamento da empresa ontem foi de R${faturamento}

Tamo junto, abs.
"""

paragrafo = documento.add_paragraph(texto) 

# alinha o paragrafo centralizado
paragrafo.alignment = WD_PARAGRAPH_ALIGNMENT.CENTER

documento.save("Texto3.docx")

# %% [markdown]
# ### Inserir Imagem

# %%
# criando o documento no Python
documento = Document()

for secao in documento.sections:
    secao.top_margin = Cm(0.5)
    secao.bottom_margin = Cm(1)
    secao.left_margin = Cm(1)
    secao.right_margin = Cm(1)


faturamento = 1000

# aqui você edita tudo o que você quer
texto = f"""Fala Lira,

O faturamento da empresa ontem foi de R${faturamento}

Tamo junto, abs.
"""

paragrafo = documento.add_paragraph(texto)

# adiciona a imagem com o valor da largura e altura
imagem = documento.add_picture("imagem.png", width=Cm(4), height=Cm(4))

documento.save("TextoComImagem.docx")

# %% [markdown]
# ### Inserir Tabela

# %%
documento = Document()

records = (
    (3, '101', 'Spam'),
    (7, '422', 'Eggs'),
    (4, '631', 'Spam, spam, eggs, and spam')
)

# observe como inserimos o estilo por meio do argumento nomeado style, podemos ver a lista de estilos disponiveis com o loop abaixo
table = documento.add_table(rows=1, cols=3, style="Light Grid Accent 1")
hdr_cells = table.rows[0].cells
hdr_cells[0].text = 'Qty'
hdr_cells[1].text = 'Id'
hdr_cells[2].text = 'Desc'
for qty, id, desc in records:
    row_cells = table.add_row().cells
    row_cells[0].text = str(qty)
    row_cells[1].text = id
    row_cells[2].text = desc
    
    
documento.save("Tabela.docx")

# %% [markdown]
# ### Para verificar todos os estilos de um arquivo:

# %%
# vai mostrar todos os estilos disponiveis para documento que foi o ultimo arquivo criado com Document()
for estilo in documento.styles:
    print(estilo)
# Out:
# _ParagraphStyle('Normal') id: 2806955903248
# _ParagraphStyle('Header') id: 2806921574432
# <docx.styles.style._CharacterStyle object at 0x0000028D8B9C0910>
# _ParagraphStyle('Footer') id: 2806921574432
# <docx.styles.style._CharacterStyle object at 0x0000028D8B9C0910>
# _ParagraphStyle('Heading 1') id: 2806921574432
# _ParagraphStyle('Heading 2') id: 2806955903248
# _ParagraphStyle('Heading 3') id: 2806921574432
# _ParagraphStyle('Heading 4') id: 2806955903248
# _ParagraphStyle('Heading 5') id: 2806921574432
# _ParagraphStyle('Heading 6') id: 2806955903248
# _ParagraphStyle('Heading 7') id: 2806921574432
# _ParagraphStyle('Heading 8') id: 2806955903248
# _ParagraphStyle('Heading 9') id: 2806921574432
# <docx.styles.style._CharacterStyle object at 0x0000028D8B9C0910>
# _TableStyle('Normal Table') id: 2806921574432
# <docx.styles.style._NumberingStyle object at 0x0000028D8B9C0910>
# _ParagraphStyle('No Spacing') id: 2806921574432
# <docx.styles.style._CharacterStyle object at 0x0000028D8B9C0910>
# <docx.styles.style._CharacterStyle object at 0x0000028D89903820>
# <docx.styles.style._CharacterStyle object at 0x0000028D8B9C0910>
# _ParagraphStyle('Title') id: 2806921574432
# <docx.styles.style._CharacterStyle object at 0x0000028D8B9C0910>
# _ParagraphStyle('Subtitle') id: 2806921574432
# <docx.styles.style._CharacterStyle object at 0x0000028D8B9C0910>
# _ParagraphStyle('List Paragraph') id: 2806921574432
# _ParagraphStyle('Body Text') id: 2806955903248
# <docx.styles.style._CharacterStyle object at 0x0000028D89903820>
# _ParagraphStyle('Body Text 2') id: 2806955903248
# <docx.styles.style._CharacterStyle object at 0x0000028D89903820>
# _ParagraphStyle('Body Text 3') id: 2806955903248
# <docx.styles.style._CharacterStyle object at 0x0000028D89903820>
# _ParagraphStyle('List') id: 2806955903248
# _ParagraphStyle('List 2') id: 2806921574432
# _ParagraphStyle('List 3') id: 2806955903248
# _ParagraphStyle('List Bullet') id: 2806921574432
# _ParagraphStyle('List Bullet 2') id: 2806955903248
# _ParagraphStyle('List Bullet 3') id: 2806921574432
# _ParagraphStyle('List Number') id: 2806955903248
# _ParagraphStyle('List Number 2') id: 2806921574432
# _ParagraphStyle('List Number 3') id: 2806955903248
# _ParagraphStyle('List Continue') id: 2806921574432
# _ParagraphStyle('List Continue 2') id: 2806955903248
# _ParagraphStyle('List Continue 3') id: 2806921574432
# _ParagraphStyle('macro') id: 2806955903248
# <docx.styles.style._CharacterStyle object at 0x0000028D89903820>
# _ParagraphStyle('Quote') id: 2806955903248
# <docx.styles.style._CharacterStyle object at 0x0000028D89903820>
# <docx.styles.style._CharacterStyle object at 0x0000028D8B9C0910>
# <docx.styles.style._CharacterStyle object at 0x0000028D89903820>
# <docx.styles.style._CharacterStyle object at 0x0000028D8B9C0910>
# <docx.styles.style._CharacterStyle object at 0x0000028D89903820>
# <docx.styles.style._CharacterStyle object at 0x0000028D8B9C0910>
# <docx.styles.style._CharacterStyle object at 0x0000028D89903820>
# _ParagraphStyle('Caption') id: 2806955903248
# <docx.styles.style._CharacterStyle object at 0x0000028D89903820>
# <docx.styles.style._CharacterStyle object at 0x0000028D8B9C0910>
# _ParagraphStyle('Intense Quote') id: 2806921574432
# <docx.styles.style._CharacterStyle object at 0x0000028D8B9C0910>
# <docx.styles.style._CharacterStyle object at 0x0000028D89903820>
# <docx.styles.style._CharacterStyle object at 0x0000028D8B9C0910>
# <docx.styles.style._CharacterStyle object at 0x0000028D89903820>
# <docx.styles.style._CharacterStyle object at 0x0000028D8B9C0910>
# <docx.styles.style._CharacterStyle object at 0x0000028D89903820>
# _ParagraphStyle('TOC Heading') id: 2806955903248
# _TableStyle('Table Grid') id: 2806921574432
# _TableStyle('Light Shading') id: 2806955903248
# _TableStyle('Light Shading Accent 1') id: 2806921574432
# _TableStyle('Light Shading Accent 2') id: 2806955903248
# _TableStyle('Light Shading Accent 3') id: 2806921574432
# _TableStyle('Light Shading Accent 4') id: 2806955903248
# _TableStyle('Light Shading Accent 5') id: 2806921574432
# _TableStyle('Light Shading Accent 6') id: 2806955903248
# _TableStyle('Light List') id: 2806921574432
# _TableStyle('Light List Accent 1') id: 2806955903248
# _TableStyle('Light List Accent 2') id: 2806921574432
# _TableStyle('Light List Accent 3') id: 2806955903248
# _TableStyle('Light List Accent 4') id: 2806921574432
# _TableStyle('Light List Accent 5') id: 2806955903248
# _TableStyle('Light List Accent 6') id: 2806921574432
# _TableStyle('Light Grid') id: 2806955903248
# _TableStyle('Light Grid Accent 1') id: 2806921574432
# _TableStyle('Light Grid Accent 2') id: 2806955903248
# _TableStyle('Light Grid Accent 3') id: 2806921574432
# _TableStyle('Light Grid Accent 4') id: 2806955903248
# _TableStyle('Light Grid Accent 5') id: 2806921574432
# _TableStyle('Light Grid Accent 6') id: 2806955903248
# _TableStyle('Medium Shading 1') id: 2806921574432
# _TableStyle('Medium Shading 1 Accent 1') id: 2806955903248
# _TableStyle('Medium Shading 1 Accent 2') id: 2806921574432
# _TableStyle('Medium Shading 1 Accent 3') id: 2806955903248
# _TableStyle('Medium Shading 1 Accent 4') id: 2806921574432
# _TableStyle('Medium Shading 1 Accent 5') id: 2806955903248
# _TableStyle('Medium Shading 1 Accent 6') id: 2806921574432
# _TableStyle('Medium Shading 2') id: 2806955903248
# _TableStyle('Medium Shading 2 Accent 1') id: 2806921574432
# _TableStyle('Medium Shading 2 Accent 2') id: 2806955903248
# _TableStyle('Medium Shading 2 Accent 3') id: 2806921574432
# _TableStyle('Medium Shading 2 Accent 4') id: 2806955903248
# _TableStyle('Medium Shading 2 Accent 5') id: 2806921574432
# _TableStyle('Medium Shading 2 Accent 6') id: 2806955903248
# _TableStyle('Medium List 1') id: 2806921574432
# _TableStyle('Medium List 1 Accent 1') id: 2806955903248
# _TableStyle('Medium List 1 Accent 2') id: 2806921574432
# _TableStyle('Medium List 1 Accent 3') id: 2806955903248
# _TableStyle('Medium List 1 Accent 4') id: 2806921574432
# _TableStyle('Medium List 1 Accent 5') id: 2806955903248
# _TableStyle('Medium List 1 Accent 6') id: 2806921574432
# _TableStyle('Medium List 2') id: 2806955903248
# _TableStyle('Medium List 2 Accent 1') id: 2806921574432
# _TableStyle('Medium List 2 Accent 2') id: 2806955903248
# _TableStyle('Medium List 2 Accent 3') id: 2806921574432
# _TableStyle('Medium List 2 Accent 4') id: 2806955903248
# _TableStyle('Medium List 2 Accent 5') id: 2806921574432
# _TableStyle('Medium List 2 Accent 6') id: 2806955903248
# _TableStyle('Medium Grid 1') id: 2806921574432
# _TableStyle('Medium Grid 1 Accent 1') id: 2806955903248
# _TableStyle('Medium Grid 1 Accent 2') id: 2806921574432
# _TableStyle('Medium Grid 1 Accent 3') id: 2806955903248
# _TableStyle('Medium Grid 1 Accent 4') id: 2806921574432
# _TableStyle('Medium Grid 1 Accent 5') id: 2806955903248
# _TableStyle('Medium Grid 1 Accent 6') id: 2806921574432
# _TableStyle('Medium Grid 2') id: 2806955903248
# _TableStyle('Medium Grid 2 Accent 1') id: 2806921574432
# _TableStyle('Medium Grid 2 Accent 2') id: 2806955903248
# _TableStyle('Medium Grid 2 Accent 3') id: 2806921574432
# _TableStyle('Medium Grid 2 Accent 4') id: 2806955903248
# _TableStyle('Medium Grid 2 Accent 5') id: 2806921574432
# _TableStyle('Medium Grid 2 Accent 6') id: 2806955903248
# _TableStyle('Medium Grid 3') id: 2806921574432
# _TableStyle('Medium Grid 3 Accent 1') id: 2806955903248
# _TableStyle('Medium Grid 3 Accent 2') id: 2806921574432
# _TableStyle('Medium Grid 3 Accent 3') id: 2806955903248
# _TableStyle('Medium Grid 3 Accent 4') id: 2806921574432
# _TableStyle('Medium Grid 3 Accent 5') id: 2806955903248
# _TableStyle('Medium Grid 3 Accent 6') id: 2806921574432
# _TableStyle('Dark List') id: 2806955903248
# _TableStyle('Dark List Accent 1') id: 2806921574432
# _TableStyle('Dark List Accent 2') id: 2806955903248
# _TableStyle('Dark List Accent 3') id: 2806921574432
# _TableStyle('Dark List Accent 4') id: 2806955903248
# _TableStyle('Dark List Accent 5') id: 2806921574432
# _TableStyle('Dark List Accent 6') id: 2806955903248
# _TableStyle('Colorful Shading') id: 2806921574432
# _TableStyle('Colorful Shading Accent 1') id: 2806955903248
# _TableStyle('Colorful Shading Accent 2') id: 2806921574432
# _TableStyle('Colorful Shading Accent 3') id: 2806955903248
# _TableStyle('Colorful Shading Accent 4') id: 2806921574432
# _TableStyle('Colorful Shading Accent 5') id: 2806955903248
# _TableStyle('Colorful Shading Accent 6') id: 2806921574432
# _TableStyle('Colorful List') id: 2806955903248
# _TableStyle('Colorful List Accent 1') id: 2806921574432
# _TableStyle('Colorful List Accent 2') id: 2806955903248
# _TableStyle('Colorful List Accent 3') id: 2806921574432
# _TableStyle('Colorful List Accent 4') id: 2806955903248
# _TableStyle('Colorful List Accent 5') id: 2806921574432
# _TableStyle('Colorful List Accent 6') id: 2806955903248
# _TableStyle('Colorful Grid') id: 2806921574432
# _TableStyle('Colorful Grid Accent 1') id: 2806955903248
# _TableStyle('Colorful Grid Accent 2') id: 2806921574432
# _TableStyle('Colorful Grid Accent 3') id: 2806955903248
# _TableStyle('Colorful Grid Accent 4') id: 2806921574432
# _TableStyle('Colorful Grid Accent 5') id: 2806955903248
# _TableStyle('Colorful Grid Accent 6') id: 2806921574432

# %% [markdown]
# ### Adaptar um documento

# %%
from datetime import datetime

# utilizaremos um template pois o python vai identificar os campos a serem substituidos
contrato = Document("Contrato.docx")

# faremos um exemplo simplificado no qual os valores abaixos virao de hard code, mas normalmente podem vir de variaveis, banco de dados ou planilha entre outros
nome = "Lira da Hashtag"
item1 = "Serviço de Treinamento em Excel"
item2 = "Apostila Completa de Excel"
item3 = "Serviço de Treinamentos de Python"

# agora faremos um par chave valor com um dicionario onde o que está preenchido no modelo (template) recebera os valores definidos nas variaveis
dicionario_valores = {
    "XXXX": nome,
    "YYYY": item1,
    "ZZZZ": item2,
    "WWWW": item3,
    "DD": str(datetime.now().day),
    "MM": str(datetime.now().month),
    "AAAA": str(datetime.now().year),
}

print(datetime.now())


# tem alguma função replace? -> é executada por parágrafo
# percorrer as linhas
    # se a linha tiver o texto xxxx substitui pelo nome
for paragrafo in contrato.paragraphs:
    # para cada placeholder do dicionario
    for codigo in dicionario_valores:
        if codigo in paragrafo.text:
            paragrafo.text = paragrafo.text.replace(codigo, dicionario_valores[codigo])

contrato.save(f"Contrato Atualizado - {nome}.docx")
# Out:
# 2023-05-10 13:33:32.228213
