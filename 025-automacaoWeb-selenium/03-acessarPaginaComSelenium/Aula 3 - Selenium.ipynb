# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)
# Out:
# [WDM] - Downloading: 100%|██████████| 6.79M/6.79M [00:00<00:00, 19.4MB/s]

# %%
# navegador.get(r'C:\Users\Jorge\Desktop\hashtag\hashtagPython\025-automacaoWeb-selenium\03-acessarPaginaComSelenium\teste.html')

navegador.get(r'C:\Users\Jorge\Desktop\hashtag\hashtagPython\025-automacaoWeb-selenium\03-acessarPaginaComSelenium\Pagina Hashtag.html')

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: webdriver-manager in c:\users\jorge\appdata\roaming\python\python311\site-packages (3.8.5)
# Requirement already satisfied: requests in c:\users\jorge\appdata\roaming\python\python311\site-packages (from webdriver-manager) (2.28.2)
# Requirement already satisfied: python-dotenv in c:\users\jorge\appdata\roaming\python\python311\site-packages (from webdriver-manager) (1.0.0)
# Requirement already satisfied: tqdm in c:\users\jorge\appdata\roaming\python\python311\site-packages (from webdriver-manager) (4.65.0)
# Requirement already satisfied: packaging in c:\users\jorge\appdata\roaming\python\python311\site-packages (from webdriver-manager) (23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jorge\appdata\roaming\python\python311\site-packages (from requests->webdriver-manager) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jorge\appdata\roaming\python\python311\site-packages (from requests->webdriver-manager) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jorge\appdata\roaming\python\python311\site-packages (from requests->webdriver-manager) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jorge\appdata\roaming\python\python311\site-packages (from requests->webdriver-manager) (2022.12.7)
# Requirement already satisfied: colorama in c:\users\jorge\appdata\roaming\python\python311\site-packages (from tqdm->webdriver-manager) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: selenium in c:\users\jorge\appdata\roaming\python\python311\site-packages (4.8.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\jorge\appdata\roaming\python\python311\site-packages (from selenium) (1.26.15)
# Requirement already satisfied: trio~=0.17 in c:\users\jorge\appdata\roaming\python\python311\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\jorge\appdata\roaming\python\python311\site-packages (from selenium) (0.10.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\jorge\appdata\roaming\python\python311\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\jorge\appdata\roaming\python\python311\site-packages (from trio~=0.17->selenium) (22.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\jorge\appdata\roaming\python\python311\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\jorge\appdata\roaming\python\python311\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in c:\users\jorge\appdata\roaming\python\python311\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\jorge\appdata\roaming\python\python311\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\jorge\appdata\roaming\python\python311\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\jorge\appdata\roaming\python\python311\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: exceptiongroup in c:\users\jorge\appdata\roaming\python\python311\site-packages (from trio-websocket~=0.9->selenium) (1.1.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\jorge\appdata\roaming\python\python311\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\jorge\appdata\roaming\python\python311\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\jorge\appdata\roaming\python\python311\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\jorge\appdata\roaming\python\python311\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.
