# %% [markdown]
# ### Documentação Selenium:
#
# - https://selenium-python.readthedocs.io/locating-elements.html

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

# %%
import os

caminho = os.getcwd()
arquivo = caminho + r"\Pagina Hashtag.html"
navegador.get(arquivo)

from selenium.webdriver.common.by import By

# %% [markdown]
# Pegar todos os links das imagens:

# %%
# aqui pegamos todos os elementos que possuem a tag figure, que é o que envolve as imagens grandes do site
listaElementos=navegador.find_elements(By.TAG_NAME,'figure')
print(listaElementos)
print(len(listaElementos))

# buscaremos os links de cada imagem dentro da tag <a> que esta dentro da tag <figure>, atributo href
for elemento in listaElementos:
    link=elemento.find_element(By.TAG_NAME,'a').get_attribute('href')
    print(link)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="65e81c300e89929e8b0e55ae9e01d5ed", element="9176eaf6-91b7-4c9c-915d-4555375b28c7")>, <selenium.webdriver.remote.webelement.WebElement (session="65e81c300e89929e8b0e55ae9e01d5ed", element="d9482001-9346-4362-b76c-7bc768247d63")>, <selenium.webdriver.remote.webelement.WebElement (session="65e81c300e89929e8b0e55ae9e01d5ed", element="10ed145e-1cd6-4cb0-b4b7-64a2895b0bcf")>, <selenium.webdriver.remote.webelement.WebElement (session="65e81c300e89929e8b0e55ae9e01d5ed", element="8f2d389c-1aaf-4177-839b-e52cf7e41bf4")>, <selenium.webdriver.remote.webelement.WebElement (session="65e81c300e89929e8b0e55ae9e01d5ed", element="bc2dd1ce-6ca6-4584-bcfd-7aeb0bd018b6")>, <selenium.webdriver.remote.webelement.WebElement (session="65e81c300e89929e8b0e55ae9e01d5ed", element="12a4c4de-0636-4c47-a948-964ffb5d4597")>]
# 6
# https://www.hashtagtreinamentos.com/curso-de-excel-online
# https://www.hashtagtreinamentos.com/curso-power-bi
# https://www.hashtagtreinamentos.com/curso-python
# https://www.hashtagtreinamentos.com/curso-sql
# https://www.hashtagtreinamentos.com/curso-vba-excel
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[10], line 8
#       6 # buscaremos os links de cada imagem dentro da tag <a> que esta dentro da tag <figure>, atributo href
#       7 for elemento in listaElementos:
# ----> 8     link=elemento.find_element(By.TAG_NAME,'a').get_attribute('href')
#       9     print(link)
#
# File c:\Python3.9.5\lib\site-packages\selenium\webdriver\remote\webelement.py:425, in WebElement.find_element(self, by, value)
#     422     by = By.CSS_SELECTOR
#     423     value = f'[name="{value}"]'
# --> 425 return self._execute(Command.FIND_CHILD_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Python3.9.5\lib\site-packages\selenium\webdriver\remote\webelement.py:403, in WebElement._execute(self, command, params)
#     401     params = {}
#     402 params["id"] = self._id
# --> 403 return self._parent.execute(command, params)
#
# File c:\Python3.9.5\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Python3.9.5\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"tag name","selector":"a"}
#   (Session info: chrome=111.0.5563.111)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x010EDCE3]
# 	(No symbol) [0x010839D1]
# 	(No symbol) [0x00F94DA8]
# 	(No symbol) [0x00FC019F]
# 	(No symbol) [0x00FC03AB]
# 	(No symbol) [0x00FB87D1]
# 	(No symbol) [0x00FDAF14]
# 	(No symbol) [0x00FB8726]
# 	(No symbol) [0x00FDB224]
# 	(No symbol) [0x00FED57C]
# 	(No symbol) [0x00FDACC6]
# 	(No symbol) [0x00FB6F68]
# 	(No symbol) [0x00FB80CD]
# 	GetHandleVerifier [0x01363832+2506274]
# 	GetHandleVerifier [0x01399794+2727300]
# 	GetHandleVerifier [0x0139E36C+2746716]
# 	GetHandleVerifier [0x01196690+617600]
# 	(No symbol) [0x0108C712]
# 	(No symbol) [0x01091FF8]
# 	(No symbol) [0x010920DB]
# 	(No symbol) [0x0109C63B]
# 	BaseThreadInitThunk [0x76A100F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77D67BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77D67B8E+238]
