# %% [markdown]
# ### Documentação Selenium:
#
# - https://selenium-python.readthedocs.io/locating-elements.html

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

# %%
import os

caminho = os.getcwd()
arquivo = caminho + r"\Pagina Hashtag.html"
navegador.get(arquivo)

from selenium.webdriver.common.by import By

# %% [markdown]
# Pegar todos os links das imagens:

# %%
# aqui pegamos todos os elementos que possuem a tag figure, que é o que envolve as imagens grandes do site
listaElementos=navegador.find_elements(By.TAG_NAME,'figure')
print(listaElementos)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="67499aedaeaa80b14cc37ca920bf0d31", element="aabf7f4c-1035-48d0-a982-33c76a593fa9")>, <selenium.webdriver.remote.webelement.WebElement (session="67499aedaeaa80b14cc37ca920bf0d31", element="102d3777-bc4b-45ce-9fbf-8aa1220d4f36")>, <selenium.webdriver.remote.webelement.WebElement (session="67499aedaeaa80b14cc37ca920bf0d31", element="699cc0e1-0538-4753-bab1-5ef4c055761d")>, <selenium.webdriver.remote.webelement.WebElement (session="67499aedaeaa80b14cc37ca920bf0d31", element="4f084c00-9328-4ea7-9853-d7fd7059083d")>, <selenium.webdriver.remote.webelement.WebElement (session="67499aedaeaa80b14cc37ca920bf0d31", element="c1529311-b5de-41b7-942e-44eb93d7fc41")>, <selenium.webdriver.remote.webelement.WebElement (session="67499aedaeaa80b14cc37ca920bf0d31", element="ff7ff56d-7660-4ea1-80f0-554970fd3f87")>]
